# %%
def closest_pair(p):
    n = len(p)                          #점의 전체 개수
    mindist = float("inf")              #최근접 거리 초기화(무한대)
    for i in range(n-1):
        for j in range(i+1, n):
            dist = distance(p[i], p[j]) #유클리드 거리 계산
            if dist < mindist:
                mindist = dist
    return mindist

# %%
import math
def distance(p1,p2):
    return math.sqrt((p1[0]-p2[0])**2+(p1[1]-p2[1])**2)
def closest_pair(p):
    n = len(p)                          
    mindist = float("inf")              
    for i in range(n-1):
        for j in range(i+1, n):
            dist = distance(p[i], p[j]) 
            if dist < mindist:
                mindist = dist
    return mindist
p =[(2, 3), (12, 30), (40, 50), (5, 1), (12, 10), (3, 4)]
print("최근접 거리", closest_pair(p))
# Out:
# 최근접 거리 1.4142135623730951

# %% [markdown]
# ### 알고리즘 예제 3.4
# ##### 문제 정의 : 2차원 평면상에 n개의 점이 있다. 가장 인접한 쌍의 거리를 구하라.
# ##### 알고리즘 설명 : 가능한 모든 점의 쌍 (p_i,p_j)에 거리를 계산하고, 가장 짧은 것을 찾는다.
# ##### 손으로 푼 예제 :![image.png](attachment:image.png)
# ##### 알고리즘 개요 : (입력) data / (출력) 최근접 쌍의 거리 / (함수) closest_pair(p)
# ##### 수행 결과 : ![image-2.png](attachment:image-2.png)
# ##### 복잡도 분석 : O(n^2)
