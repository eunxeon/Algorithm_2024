# %% [markdown]
# ### 알고리즘 예제 7.10
# ##### 문제 정의 : Floyd의 최단경로 탐색 알고리즘
# ##### 알고리즘 설명 : 인덱스가 0으로 시작하는 것과 리스트의 리스트로 구현된 이차원 인접 행렬W를 같은 형태의 D행렬에 복사하는 코드에 유의해야한다.파이썬에서는 객체의 깊은 복사를 위해 copy모듈을 제공하고,이 모듈의 deepcopy()함수를 이용해 리스트의 리스트 구조인 W를 D로 복사하였다.
# ##### 손으로 푼 예제 : ![image.png](attachment:image.png)
# ##### 알고리즘 개요 : D = list(W) 2차원 배열의 복사,for i in range(len(W)):D[i]=list(W[i])각 행에 대해 해당 행의 리스트를 복사,import copy #copy 모듈 포함,D=copy.deepcopy(W) # deepcopy()함수를 이용한 깊은 복사
# ##### 수행 결과 : ![7.10실행결과.png](attachment:7.10실행결과.png)
# ##### 복잡도 분석 : Floyd의 알고리즘은 3중 루프로 이루어져 있고, 각 루프가 최대 n번 반복한다.따라서 시간 복잡도가 O(n^3)이다.추가적인 메모리 D를 위한 공간 복잡도는 O(n^2)이다.

# %%
##알고리즘 코드
import copy
def shortest_path_floyd(vertex,w):
    vsize_len(vertex)
    D=copy.deepcopy(W)

    for k in range(vsize):
        for i in range(vsize):
            for j in range(vsize):
                if(D[i][k]+D[k][j]<D[i][j]):
                    D[i][j]=D[i][k]+D[k][j]
    printD(D)

# %%
import copy
def shortest_path_floyd(vertex,W):
    vsize=len(vertex)
    D=copy.deepcopy(W)

    for k in range(vsize):
        for i in range(vsize):
            for j in range(vsize):
                if(D[i][k]+D[k][j]<D[i][j]):
                    D[i][j]=D[i][k]+D[k][j]
        printD(D) 

def printD(D):
    vsize=len(D)
    print("==========================================")
    for i in range(vsize):
        for j in range(vsize):
            if(D[i][j]==INF):print("  INF",end=' ')
            else:print("%4d "%D[i][j],end=' ')
        print(" ")
INF=9999
vertex=['A','B','C','D','E','F','G']
weight=[[0,7,INF,INF,3,10,INF],[7,0,4,10,2,6,INF],[INF,4,0,2,INF,INF,INF],[INF,10,2,0,11,9,4],[3,2,INF,11,0,13,5],[10,6,INF,9,13,0,INF],[INF,INF,INF,4,5,INF,0]]
print("Shortest Path By Floyd's Algorithm")
shortest_path_floyd(vertex,weight)
# Out:
# Shortest Path By Floyd's Algorithm
# ...
#    0     7    INF   INF    3    10    INF
#    7     0     4    10     2     6    INF
#   INF    4     0     2    INF   INF   INF
#   INF   10     2     0    11     9     4
#    3     2    INF   11     0    13     5
#   10     6    INF    9    13     0    INF
#   INF   INF   INF    4     5    INF    0
# ...
#    0     7    11    17     3    10    INF
#    7     0     4    10     2     6    INF
#   11     4     0     2     6    10    INF
#   17    10     2     0    11     9     4
#    3     2     6    11     0     8     5
#   10     6    10     9     8     0    INF
#   INF   INF   INF    4     5    INF    0
# ...
#    0     7    11    13     3    10    INF
#    7     0     4     6     2     6    INF
#   11     4     0     2     6    10    INF
#   13     6     2     0     8     9     4
#    3     2     6     8     0     8     5
#   10     6    10     9     8     0    INF
#   INF   INF   INF    4     5    INF    0
# ...
#    0     7    11    13     3    10    17
# ...
