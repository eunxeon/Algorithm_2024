# %% [markdown]
# ### 알고리즘 예제 8.1
# ##### 문제 정의 : 거스름돈 최소화 알고리즘(탐욕적 기법)
# ##### 알고리즘 설명 : coins는 모든 동전의 액면가 리스트로 반드시 내림차순으로 정렬하고 각 액면가 동전의 개수를 저장하는 리스트를 만들어 액면가가 높은 동전부터 모든 동전에 대해 현재 액면가를 최대한 사용하는 동전 개수를 계산해 리스트에 넣고, 남은 거스름돈을 계산한다.최종적으로 각 액면가 동전의 개수 리스트를 반환한다.
# ##### 손으로 푼 예제 : ![8.1손으로푼예제.png](attachment:8.1손으로푼예제.png)
# ##### 알고리즘 개요 : 거스름돈의 액수가 V가 주어지면 액면가가 가장 높은 동전을 이용하여 먼저 잔돈의 액수를 최대한으로 줄이고 남은 액수는 다음 액면가의 동전을 최대한으로 사용하는 과정을 순서에 따라 반복한다.
# ##### 수행 결과 : ![8.1수행결과.png](attachment:8.1수행결과.png)
# ##### 복잡도 분석 : 3행에서 동전의 종류만큼 루프를 반복하므로 동전의 액면가가 m가지라면 시간 복잡도는 O(m)이다

# %%
##알고리즘 코드
def min_coins_greedy(coinss,V):
    count = []
    for i in range(len(coins)):
        cnt=V // coins[i]
        count.append(cnt)
        V -= cnt * coins[i]
    return count
# Out:
# 잔돈 액수= 580
# 동전 종류= [500, 100, 50, 10, 5, 1]
# 동전 개수= [1, 0, 1, 3, 0, 0]

# %%
##테스트 코드
def min_coins_greedy(coinss,V):
    count = []
    for i in range(len(coins)):
        cnt=V // coins[i]
        count.append(cnt)
        V -= cnt * coins[i]
    return count

coins=[500,100,50,10,5,1]
V=580
print("잔돈 액수=",V)
print("동전 종류=",coins)
print("동전 개수=",min_coins_greedy(coins,V))
# Out:
# 잔돈 액수= 580
# 동전 종류= [500, 100, 50, 10, 5, 1]
# 동전 개수= [1, 0, 1, 3, 0, 0]
