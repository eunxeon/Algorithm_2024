# %%
def sequential_search(A, key):  #A는 입력 리스트, key는 탐색 키
    for i in range(len(A)):     #i:0, 1, ...len(A)-1
        if A[i] == key:         #탐색 성공하면 (비교 연산, 기본 연산임)
            return i            #인덱스 반환
    return -1                   #탐색에 실패하면 -1반환

# %% [markdown]
# ### 알고리즘 예제 3.2
# ##### 문제 정의 : 리스트에 n개의 항목이 들어 있다. 이 리스트에서 "탐색키"를 가진 항목을 찾아라. 만약 찾는 항목이 있으면 그 항목의 인덱스를 반환하고, 없으면 -1을 반환하라. 단, 리스트의 항목들은 정렬되어 있지 않다.
# ##### 알고리즘 설명 : 입력 리스트의 첫 항목부터 순서대로 하나씩 탐색키와 비교한다.
# ##### 손으로 푼 예제 : ![image-2.png](attachment:image-2.png)
# ##### 알고리즘 개요 : (입력) data,key / (출력) 탐색 성공 시 인덱스 반환, 실패 시 -1 반환 / (함수) sequential_search(A, key)
# ##### 수행 결과 : ![image.png](attachment:image.png)
# ##### 복잡도 분석 : 최선의 경우 O(1) / 최악의 경우 O(n) / 평균적인 경우 O(n)

# %%
def sequential_search(A, key):
    for i in range(len(A)):
        if A[i] == key:
            return i
    return -1
data = [5, 3, 8, 4, 2, 7]
print("지정된 리스트 : ", data)
key = int(input("원하는 키 값을 입력하시오(리스트 속에 있어야 한다) >> "))
if(sequential_search(data,key) == -1):
    print("키 값이 리스트에 없습니다.")
else :
    print("키 값의 인덱스는 ", sequential_search(data, key), "입니다.")
# Out:
# 지정된 리스트 :  [5, 3, 8, 4, 2, 7]
# 키 값의 인덱스는  1 입니다.
