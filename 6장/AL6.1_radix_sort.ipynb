# %%
from queue import Queue                             #파이썬 queue모듈의 Queue사용
def radix_sort(A):
    queues=[]                                       #큐의 리스트
    for i in range(BUCKETS):
        queues.append(Queue())                      #BUCKETS개의 큐 사용
    n=len(A)
    factor=1                                        #1의 자리부터 시작
    for i in range(n):                              #모든 자리에 대해
        queues[(A[i]//factor)%BUCKETS].put(A[i])    #자릿수에 따라 큐에 삽입
    j=0                     
    for b in range(BUCKETS):                        #버킷에서 꺼내어 원래의 리스트로
        while not queues[b].empty():                #b번째 큐가 공백이 아닌 동안
            A[j]=queues[b].get()                    #원소를 꺼내 리스트에 저장
            j+=1
    factor *= BUCKETS                               #그 다음 자릿수로 간다.
    print("step",d+1,A)                             #중간 과정 출력용 문장

# %%
from queue import Queue                             
def radix_sort(A):
    queues=[]                                      
    for i in range(BUCKETS):
        queues.append(Queue())                      
    n=len(A)
    factor=1 
    for d in range(DIGITS):                                       
        for i in range(n):                              
            queues[(A[i]//factor)%BUCKETS].put(A[i])    
        j=0                     
        for b in range(BUCKETS):                        
            while not queues[b].empty():               
                A[j]=queues[b].get()                   
                j+=1
        factor*=BUCKETS                               
        print("step",d+1,A)                            


import random   #테스트를 위한 난수 발생을 위해 random모듈 포함
BUCKETS = 10    #10진법으로 정렬
DIGITS = 4      #최대 4자릿수
data = []
for i in range(10):
    data.append(random.randint(1,9999)) #1~9999 사이의 숫자 10개 생성
radix_sort(data)                        #기수 정렬
print("Radix: ",data)                   #결과 출력
# Out:
# step 1 [3830, 3102, 6934, 3964, 1996, 4656, 8156, 1208, 1248, 7529]
# step 2 [3102, 1208, 7529, 3830, 6934, 1248, 4656, 8156, 3964, 1996]
# step 3 [3102, 8156, 1208, 1248, 7529, 4656, 3830, 6934, 3964, 1996]
# step 4 [1208, 1248, 1996, 3102, 3830, 3964, 4656, 6934, 7529, 8156]
# Radix:  [1208, 1248, 1996, 3102, 3830, 3964, 4656, 6934, 7529, 8156]

# %% [markdown]
# ### 알고리즘 예제 6.1
# ##### 문제 정의 : 비교연산을 하지 않고도 데이터를 정렬할 수 있는 기수 정렬
# ##### 알고리즘 설명 : 1.항목들을 저장할 버킷들을 준비한다.
# #####                 2.입력 항목들을 순서대로 킷값에 따라 해당 버킷에 넣는다.
# #####                 3.위쪽 버킷부터 순차적으로 버킷 안에 들어 있는 숫자를 출력한다.
# ##### 손으로 푼 예제 : ![image.png](attachment:image.png)
# ##### 알고리즘 개요 : (입력) data  / (출력) 정렬된 리스트data / (함수) radix_sort(A)
# ##### 수행 결과 : ![image-2.png](attachment:image-2.png)
# ##### 복잡도 분석 : 숫자를 삽입하는 내부루프가 n번 반복하므로 O(n)
